# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset_folder = 'datasets'

# %%
uci_data = 'heart_failure_clinical_records_dataset.csv'
kaggle_path = 'Heart_Disease_and_Stroke_Prevention.csv'

# %%
uci = pd.read_csv(dataset_folder+'/'+uci_data)
kaggle = pd.read_csv(dataset_folder+'/'+kaggle_path)

# %%
cardio_path = 'cardio_train.csv'

# %%
cardio = pd.read_csv(dataset_folder+'/'+cardio_path,sep=';').set_index('id')

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 6.9 MB

# %%
print(cardio.shape)
cardio.sample(3)
# Out:
# (70000, 12)
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 57096  23245       1     155    66.0    140     90            1     1      0
# 73410  15081       1     162    75.0    110     70            1     1      1
# 83871  19704       1     156    59.0    150   1100            1     1      0
#
#        alco  active  cardio
# id
# 57096     0       1       1
# 73410     1       1       0
# 83871     0       1       1

# %%
cardio.hist(bins=50,figsize=(20,15))
plt.show()

# %%
23245/365
# Out:
# 63.68493150684932
